# %% [markdown]
# # M5 Project Paper Group 1 (MSIS 2537 FALL 2024)

# %% [markdown]
# # Data Import and Cleaning

# %%
#imports and settings
import pandas as pd
pd.set_option('future.no_silent_downcasting', True)
import time as time
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Journeys CSV

# %%
# Load journey data from CSV
journeys = pd.read_csv('journeys.csv')

# Filter for journeys in San Francisco and remove the city column
journeys = journeys[journeys['Car Parking Address City'] == 'San Francisco'].drop(columns='Car Parking Address City')

# Covert postcode to category
journeys['Car Parking Address Postcode'] = journeys['Car Parking Address Postcode'].astype('category')

# Convert specific columns to datetime format
cols = ['Trip Start At Local Time', 'Trip End At Local Time', 'Trip Created At Local Time']
journeys[cols] = journeys[cols].apply(pd.to_datetime)

# Clean and convert the trip price column to float
journeys.rename(columns={'Trip Sum Trip Price': 'Trip Price'}, inplace=True)
journeys['Trip Price'] = journeys['Trip Price'].str.replace(r"[$,\.]", "", regex=True).astype(float) / 100

# Sort journeys by start time in ascending order
journeys.sort_values(by='Trip Start At Local Time', ascending=True, inplace=True)

journeys
# Out:
#                            Trip ID Hash                       Car ID Hash  \
# 14398  41037625705e1c8c54ee2311803da479  9ddbdce433138241891c9799cfb46859
# 3968   11b010fd63336457c28d3cd747d673b2  5328fd8804d7560958b4eddfce276139
# 20711  5d9ad2b521e99deebf54cbfeeaff9682  a6bc23db01b597f8eee2378305747412
# 43917  c7636937599182c1ed7effe0ac8c2f0d  b5e9271dd09182abab262d7c8453d5e5
# 27485  7cab48e204def19250c79cbc24ef307a  31daeb68bf1fd988e7dcf6a5976acd49
# ...                                 ...                               ...
# 43783  c6d201f4d6e66b0de13598118c55d8ec  046065e6f1433794f9d051bae3c2d850
# 19735  59705d88d67a2e60f8ec5084cd9def35  9ddbdce433138241891c9799cfb46859
# 3150   0df125971dff90f587bc8de4858d8844  93f34c89e36e37f6187df8708b41ed62
# 49454  e0118e8190fc1196ea5df23374c79478  8ebd24949be530b67600a9b11bac7e4e
# 25474  734442647492d7fe141d75a71e13b460  5cfeba13d65aaea9e746281dcf89883a
#
#       Car Parking Address Postcode Trip Start At Local Time  \
# 14398                        94122      2017-01-01 09:30:00
# 3968                         94117      2017-01-01 10:15:00
# 20711                        94109      2017-01-01 10:30:00
# 43917                        94115      2017-01-01 10:30:00
# 27485                        94110      2017-01-01 10:30:00
# ...                            ...                      ...
# 43783                        94112      2017-12-30 22:00:00
# 19735                        94122      2017-12-30 22:45:00
# 3150                         94110      2017-12-30 23:00:00
# 49454                        94103      2017-12-30 23:45:00
# 25474                        94133      2017-12-30 23:45:00
#
#       Trip End At Local Time Trip Created At Local Time  Trip Price
# 14398    2017-01-01 17:00:00        2017-01-01 09:28:42       60.00
# 3968     2017-01-02 10:00:00        2017-01-01 10:03:48       80.00
# 20711    2017-01-01 15:30:00        2016-12-30 15:58:45       45.00
# 43917    2017-01-01 20:30:00        2016-12-31 19:25:54       90.00
# 27485    2017-01-01 18:30:00        2016-12-31 22:02:50       68.00
# ...                      ...                        ...         ...
# 43783    2017-12-31 01:00:00        2017-12-30 21:11:54       18.75
# 19735    2018-01-01 15:30:00        2017-12-30 17:40:03      128.05
# 3150     2017-12-31 04:15:00        2017-12-30 20:05:45       26.25
# 49454    2017-12-31 09:30:00        2017-12-30 09:34:41       48.75
# 25474    2017-12-31 02:45:00        2017-12-30 13:04:23       19.68
#
# [36154 rows x 7 columns]

# %% [markdown]
# ## Utilization CSV

# %%
# Load CSV file
utilization = pd.read_csv('utilization.csv')

# Convert time column to datetime format
utilization['Car Hourly Utilization Aggregated At Time'] = pd.to_datetime(utilization['Car Hourly Utilization Aggregated At Time'])

# Rename columns for clarity
utilization.rename(columns={
    'Car Hourly Utilization Sum Available Minutes': 'Car Available Minutes',
    'Car Hourly Utilization Sum Utilized Minutes': 'Car Used Minutes'
}, inplace=True)

# Filter rows to include only cars present in the journeys DataFrame
utilization = utilization[utilization['Car ID Hash'].isin(journeys['Car ID Hash'])]

#create utilization % column, drop available and used minutes
utilization['Utilization'] = utilization['Car Used Minutes']/utilization['Car Available Minutes']
utilization.drop(columns = ['Car Used Minutes', 'Car Available Minutes'], inplace = True)

# Sort by time column
utilization = utilization.sort_values(by='Car Hourly Utilization Aggregated At Time')

utilization
# Out:
# <ipython-input-3-70cd859b3962>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utilization['Utilization'] = utilization['Car Used Minutes']/utilization['Car Available Minutes']
# <ipython-input-3-70cd859b3962>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utilization.drop(columns = ['Car Used Minutes', 'Car Available Minutes'], inplace = True)
#                               Car ID Hash  \
# 2256014  d8377fc52752d07adee8aacbbf87dbfe
# 1791832  adff5e22a393de23e82444e1abb5215d
# 969142   622e5272a5fc0bbbbbd935b99762447f
# 1817370  b1512d5d9b6140eb341578f80f4e5785
# 955478   6190fdc0e9dd4957ec45360262dc98a0
# ...                                   ...
# 1981068  be88e01934f647a731bcd679d77e844e
# 2273483  d88adcb1e702c280716302cb218d4473
# 1022117  643b27320a0a43f302f8cada0fd9a2c5
# 1783096  ad5b0ff5edb01efe41acf0999accf446
# 2635184  ff8da434b5228d922f2845ececf691ec
#
#         Car Hourly Utilization Aggregated At Time  Utilization
# 2256014                       2017-01-01 00:00:00          0.0
# 1791832                       2017-01-01 00:00:00          0.0
# 969142                        2017-01-01 00:00:00          0.0
# 1817370                       2017-01-01 00:00:00          0.0
# 955478                        2017-01-01 00:00:00          0.0
# ...                                           ...          ...
# 1981068                       2017-12-30 23:00:00          0.5
# 2273483                       2017-12-30 23:00:00          NaN
# 1022117                       2017-12-30 23:00:00          1.0
# 1783096                       2017-12-30 23:00:00          NaN
# 2635184                       2017-12-30 23:00:00          1.0
#
# [1328815 rows x 3 columns]

# %% [markdown]
# ## Final Dataframe

# %%
#all unique cars
car_list = journeys['Car ID Hash'].unique()
car_list = car_list[0:30] #30 cars due to computation challenge

print('Merging and filtering dataframes...')
start_time = time.time()

#create the final combined dataframe
df = pd.DataFrame()

for i in car_list:
    list1 = utilization[utilization['Car ID Hash'] == i]
    list2 = journeys[journeys['Car ID Hash'] == i]

    #perform a merge
    merged = list1.merge(list2, how='left')

    #filter where Utilization is between the start and end times
    merged = merged[(merged["Car Hourly Utilization Aggregated At Time"] >= merged["Trip Start At Local Time"]) &
              (merged["Car Hourly Utilization Aggregated At Time"] <= merged["Trip End At Local Time"])]

    #concat the new dataframe with the complete one
    df = pd.concat([df, merged], ignore_index=True)

#sort df by trip time start
df = df.sort_values(by = 'Car Hourly Utilization Aggregated At Time')

#generate the final dataframe
df2 = pd.DataFrame()

for i in car_list:
    list1 = utilization[utilization['Car ID Hash'] == i]
    list2 = df[df['Car ID Hash'] == i]

    #merge left "utilization" with "df" and duplicate previous row, by each car ID
    df3 = list1.merge(list2, how='left')
    df3 = df3.ffill()

    #concat the new dataframe with the complete one
    df2 = pd.concat([df2, df3], ignore_index=True)

df = df2.copy()

#time calculation
end_time = time.time()
elapsed_time = end_time - start_time

print(f'Done, elapsed time to merge was {round(elapsed_time, 2)} seconds.')

#drop NaN columns (and NaT)
df = df.replace([np.inf, -np.inf], np.nan).dropna()

#clean dataframe
#sort df by Utilization time
df = df.sort_values(by = 'Car Hourly Utilization Aggregated At Time', ignore_index=True)

#create duration column
df['Hours Duration'] = (df['Trip End At Local Time'] - df['Trip Start At Local Time']).dt.total_seconds().astype(float)/3600

#create booking advance time
df['Booking Advance Hours Duration'] = ((df['Trip Start At Local Time'] - df['Trip Created At Local Time'])
                                        .dt.total_seconds().astype(float)/3600).round(4)

#create individual start date and time columns
df[['Start Date','Start Time']] = df['Trip Start At Local Time'].astype(str).str.split(' ', expand = True)
df['Start Date'] = pd.to_datetime(df['Start Date'])
df['Start Time'] = pd.to_datetime(df['Start Time'], format = '%H:%M:%S')

#create Trip Start Day of the week column
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['Start Day of the Week'] = df['Start Date'].dt.weekday.map(lambda x: days[x])

#create Trip start month column
months = ['January', 'February', 'March', 'April', 'May', 'June',
          'July', 'August', 'September', 'October', 'November', 'December']
df['Start Month'] = df['Start Date'].dt.month.map(lambda x: months[x-1])

#create start hour column
df['Start Hour'] = df['Start Time'].dt.hour

#directly calculate hourly average price per post code
df['Hourly Post Code Average Price'] = df.groupby(['Car Hourly Utilization Aggregated At Time', 'Car Parking Address Postcode'],
                                                  observed = False)['Trip Price'].transform('mean')

#Create trip price to average price per post code column
df['Price to Average Price Per Postcode'] = (df['Trip Price']/df['Hourly Post Code Average Price']).round(2)

#drop columns not needed
df.drop(columns = ['Trip Start At Local Time', 'Trip End At Local Time', 'Trip Created At Local Time',
                   'Start Date', 'Start Time', 'Car Hourly Utilization Aggregated At Time', 'Trip ID Hash',
                  'Hourly Post Code Average Price'], inplace = True)

print(f'\nFinal Dataframe after cleaning is {len(df)} rows long')
print(f'Original Utilization dataframe was {len(utilization)} rows long')

df
# Out:
# Merging and filtering dataframes...
# Done, elapsed time to merge was 20.78 seconds.
#
# Final Dataframe after cleaning is 250544 rows long
# Original Utilization dataframe was 1328815 rows long
#                              Car ID Hash  Utilization  \
# 0       9ddbdce433138241891c9799cfb46859          1.0
# 1       a6bc23db01b597f8eee2378305747412          1.0
# 2       b5e9271dd09182abab262d7c8453d5e5          1.0
# 3       31daeb68bf1fd988e7dcf6a5976acd49          1.0
# 4       5328fd8804d7560958b4eddfce276139          1.0
# ...                                  ...          ...
# 250539  a4146ec8abbd83af7efb24e3e8f12c13          0.0
# 250540  9ddbdce433138241891c9799cfb46859          1.0
# 250541  f71f8651e3fa154855271f8ded9601d2          0.0
# 250542  4ee389e31ed04c83df66d1aee2840967          0.0
# 250543  c3bedd1001dd755b449c1da45e694387          1.0
#
#        Car Parking Address Postcode  Trip Price  Hours Duration  \
# 0                             94122       60.00            7.50
# 1                             94109       45.00            5.00
# 2                             94115       90.00           10.00
# 3                             94110       68.00            8.00
# 4                             94117       80.00           23.75
# ...                             ...         ...             ...
# 250539                        94122       36.64            4.25
# 250540                        94122      128.05           40.75
# 250541                        94102       32.64            3.00
# 250542                        94122       53.77            8.00
# 250543                        94114      107.83           29.00
#
#         Booking Advance Hours Duration Start Day of the Week Start Month  \
# 0                               0.0217                Sunday     January
# 1                              42.5208                Sunday     January
# 2                              15.0683                Sunday     January
# 3                              12.4528                Sunday     January
# 4                               0.1867                Sunday     January
# ...                                ...                   ...         ...
# 250539                          0.5908              Saturday    December
# 250540                          5.0825              Saturday    December
# 250541                          0.2739              Saturday    December
# 250542                          0.0925              Saturday    December
# 250543                         21.0419              Saturday    December
#
#         Start Hour  Price to Average Price Per Postcode
# 0                9                                 1.00
# 1               10                                 1.00
# 2               10                                 1.00
# 3               10                                 1.00
# 4               10                                 1.00
# ...            ...                                  ...
# 250539          12                                 0.72
# 250540          22                                 2.50
# 250541          16                                 0.62
# 250542           9                                 1.05
# 250543          11                                 1.67
#
# [250544 rows x 10 columns]

# %% [markdown]
# # Environmental Supervised Learning Model

# %%
#create training and test data
x = df.drop(columns = 'Utilization')
y = df['Utilization']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .2, random_state = 42)

x_train
# Out:
#                              Car ID Hash Car Parking Address Postcode  \
# 4221    76aa6d08190734decd6ab8f7b573101d                        94110
# 92712   b9bad70674669b3ac9d3aad4d681e2f6                        94102
# 120683  b1512d5d9b6140eb341578f80f4e5785                        94112
# 133331  4ee389e31ed04c83df66d1aee2840967                        94122
# 247203  5328fd8804d7560958b4eddfce276139                        94117
# ...                                  ...                          ...
# 119879  001881b594721c5b169be3a2e73c1183                        94117
# 103694  b5e9271dd09182abab262d7c8453d5e5                        94115
# 131932  d63ded6ed04143a8813121ce0611287c                        94112
# 146867  a4146ec8abbd83af7efb24e3e8f12c13                        94122
# 121958  4ee389e31ed04c83df66d1aee2840967                        94122
#
#         Trip Price  Hours Duration  Booking Advance Hours Duration  \
# 4221         96.00           26.00                          1.2458
# 92712        11.25            1.25                          0.0294
# 120683       90.00           24.00                          3.4503
# 133331       93.50           11.00                          0.0731
# 247203       72.83            8.00                          0.2922
# ...            ...             ...                             ...
# 119879       60.75            6.75                          0.6800
# 103694       20.25            2.25                         19.9894
# 131932       56.25            6.25                          0.1892
# 146867       80.00           16.00                         20.8528
# 121958       42.50            5.00                         94.5914
#
#        Start Day of the Week Start Month  Start Hour  \
# 4221                Saturday     January          10
# 92712                Tuesday         May           9
# 120683              Saturday       April          15
# 133331              Saturday        July          16
# 247203                Monday    December          13
# ...                      ...         ...         ...
# 119879                Sunday        June          10
# 103694                Sunday         May          14
# 131932              Saturday        June          11
# 146867                Friday        July           7
# 121958             Wednesday        June          11
#
#         Price to Average Price Per Postcode
# 4221                                   2.38
# 92712                                  0.22
# 120683                                 1.60
# 133331                                 1.09
# 247203                                 1.18
# ...                                     ...
# 119879                                 0.55
# 103694                                 0.44
# 131932                                 0.77
# 146867                                 0.93
# 121958                                 0.84
#
# [200435 rows x 9 columns]

# %%
#categorical and numerical column lists
categorical_list = ['Car ID Hash', 'Car Parking Address Postcode', 'Start Day of the Week', 'Start Month', 'Start Hour', ]
numerical_list = ['Trip Price', 'Hours Duration', 'Booking Advance Hours Duration', 'Price to Average Price Per Postcode']

#standard transformation
preprocessor1 = ColumnTransformer(transformers=[('categorical', OneHotEncoder(sparse_output = False, handle_unknown = 'ignore'), categorical_list),
                                              ('numerical', MinMaxScaler(), numerical_list)], remainder='passthrough')

# %% [markdown]
# ## Linear Regression

# %%
#standard Preprocessor and Linear Regression
time_start = time.time()
model_1 = make_pipeline(preprocessor1, LinearRegression())
model_1.fit(x_train, y_train)
time_end = time.time()
print(f'Train R2 Score: {model_1.score(x_train, y_train):.4f}')
print(f'Test R2 Score: {model_1.score(x_test, y_test):.4f}')
print(f'Seconds to Fit Model: {(time_end - time_start):.3f}')
# Out:
# Train R2 Score: 0.1957
# Test R2 Score: 0.2080
# Seconds to Fit Model: 2.478

# %% [markdown]
# # Reinforcement Learning Models
#
# Notes:
# - RL models interact with the SL model.
# - Compare Agent's model to the Environment's model

# %% [markdown]
# ## A/B/N Model

# %%
time_start = time.time()

# Initialization
df2 = pd.DataFrame(columns=['Utilization'] + x_train.columns.tolist())
num_iterations = len(x_train)
j = 0
last_time_check = time.time()

# Reinforcement Learning Loop
for i in range(num_iterations):
    # Agent chooses a random price
    agent_price = np.random.uniform(10, 150) #this can be adjusted

    # Get current environment features
    current_features = x_train.iloc[i][x_train.drop(columns = 'Trip Price').columns.tolist()]

    # Predict utilization using supervised learning model #1
    features_with_price = current_features.to_dict()
    features_with_price['Trip Price'] = agent_price
    features_with_price = pd.DataFrame([features_with_price])
    utilization = model_1.predict(features_with_price)[0]

    # Append the agent's data and predicted utilization to DataFrame 2
    new_row = {'Trip Price': agent_price, **current_features.to_dict(), 'Utilization': utilization}
    if df2.empty:
        df2 = pd.DataFrame([new_row])
    else:
        df2 = pd.concat([df2, pd.DataFrame([new_row])], ignore_index=True)

    # Time Check
    j += 1
    if j % 1000 == 0:
        current_time = time.time()
        time_for_last_1000 = current_time - last_time_check
        remaining_iterations = (num_iterations - j) // 1000
        estimated_time_remaining = remaining_iterations * time_for_last_1000 / 60
        last_time_check = current_time
        print(f'Completed loop {j/1000:.0f}k / {num_iterations/1000:.0f}k,',
              f'Estimated Time Remaining: {estimated_time_remaining:.2f} Minutes')

# Train supervised learning model #2 on Agent's DataFrame 2
x2_train = df2.drop(columns = 'Utilization')
y2_train = df2.Utilization

preprocessor2 = ColumnTransformer(transformers=[('categorical', OneHotEncoder(sparse_output = False, handle_unknown = 'ignore'), categorical_list),
                                              ('numerical', MinMaxScaler(), numerical_list)], remainder='passthrough')

model_2 = make_pipeline(preprocessor2, LinearRegression())
model_2.fit(x2_train, y2_train)

time_end = time.time()
print(f'Time to Train RL Model: {(time_end - time_start)/60:.2f} Minutes')

# Compare Agent's Model to the environment's model
environment_train = model_1.score(x_train, y_train)
print(f'Environment Training R2 Score: {environment_train:.4f}')

ABN_train = model_2.score(x_train, y_train)
print(f'A/B/N Training R2 Score: {ABN_train:.4f}')

environment_test = model_1.score(x_test, y_test)
print(f'Environment Test R2 Score: {environment_test:.4f}')

ABN_test = model_2.score(x_test, y_test)
print(f'A/B/N Test R2 Score: {ABN_test:.4f}')
# Out:
# Completed loop 1k / 200k, Estimated Time Remaining: 89.07 Minutes
# Completed loop 2k / 200k, Estimated Time Remaining: 79.26 Minutes
# Completed loop 3k / 200k, Estimated Time Remaining: 72.70 Minutes
# Completed loop 4k / 200k, Estimated Time Remaining: 67.54 Minutes
# Completed loop 5k / 200k, Estimated Time Remaining: 61.27 Minutes
# Completed loop 6k / 200k, Estimated Time Remaining: 59.72 Minutes
# Completed loop 7k / 200k, Estimated Time Remaining: 66.36 Minutes
# Completed loop 8k / 200k, Estimated Time Remaining: 63.19 Minutes
# Completed loop 9k / 200k, Estimated Time Remaining: 64.26 Minutes
# Completed loop 10k / 200k, Estimated Time Remaining: 59.19 Minutes
# Completed loop 11k / 200k, Estimated Time Remaining: 58.19 Minutes
# Completed loop 12k / 200k, Estimated Time Remaining: 63.28 Minutes
# Completed loop 13k / 200k, Estimated Time Remaining: 58.58 Minutes
# Completed loop 14k / 200k, Estimated Time Remaining: 57.34 Minutes
# Completed loop 15k / 200k, Estimated Time Remaining: 60.82 Minutes
# Completed loop 16k / 200k, Estimated Time Remaining: 58.55 Minutes
# Completed loop 17k / 200k, Estimated Time Remaining: 65.72 Minutes
# Completed loop 18k / 200k, Estimated Time Remaining: 58.19 Minutes
# Completed loop 19k / 200k, Estimated Time Remaining: 62.07 Minutes
# Completed loop 20k / 200k, Estimated Time Remaining: 60.60 Minutes
# Completed loop 21k / 200k, Estimated Time Remaining: 56.23 Minutes
# Completed loop 22k / 200k, Estimated Time Remaining: 54.82 Minutes
# Completed loop 23k / 200k, Estimated Time Remaining: 59.42 Minutes
# Completed loop 24k / 200k, Estimated Time Remaining: 54.47 Minutes
# Completed loop 25k / 200k, Estimated Time Remaining: 54.40 Minutes
# Completed loop 26k / 200k, Estimated Time Remaining: 58.59 Minutes
# Completed loop 27k / 200k, Estimated Time Remaining: 54.01 Minutes
# Completed loop 28k / 200k, Estimated Time Remaining: 55.60 Minutes
# Completed loop 29k / 200k, Estimated Time Remaining: 55.82 Minutes
# Completed loop 30k / 200k, Estimated Time Remaining: 57.66 Minutes
# Completed loop 31k / 200k, Estimated Time Remaining: 56.95 Minutes
# Completed loop 32k / 200k, Estimated Time Remaining: 52.63 Minutes
# Completed loop 33k / 200k, Estimated Time Remaining: 54.63 Minutes
# Completed loop 34k / 200k, Estimated Time Remaining: 54.59 Minutes
# Completed loop 35k / 200k, Estimated Time Remaining: 51.57 Minutes
# Completed loop 36k / 200k, Estimated Time Remaining: 55.70 Minutes
# Completed loop 37k / 200k, Estimated Time Remaining: 51.32 Minutes
# Completed loop 38k / 200k, Estimated Time Remaining: 52.42 Minutes
# Completed loop 39k / 200k, Estimated Time Remaining: 53.03 Minutes
# Completed loop 40k / 200k, Estimated Time Remaining: 50.47 Minutes
# Completed loop 41k / 200k, Estimated Time Remaining: 58.21 Minutes
# Completed loop 42k / 200k, Estimated Time Remaining: 51.45 Minutes
# Completed loop 43k / 200k, Estimated Time Remaining: 50.02 Minutes
# Completed loop 44k / 200k, Estimated Time Remaining: 52.65 Minutes
# Completed loop 45k / 200k, Estimated Time Remaining: 48.99 Minutes
# Completed loop 46k / 200k, Estimated Time Remaining: 52.10 Minutes
# Completed loop 47k / 200k, Estimated Time Remaining: 50.59 Minutes
# Completed loop 48k / 200k, Estimated Time Remaining: 53.77 Minutes
# Completed loop 49k / 200k, Estimated Time Remaining: 51.69 Minutes
# Completed loop 50k / 200k, Estimated Time Remaining: 47.87 Minutes
# Completed loop 51k / 200k, Estimated Time Remaining: 51.41 Minutes
# Completed loop 52k / 200k, Estimated Time Remaining: 51.28 Minutes
# Completed loop 53k / 200k, Estimated Time Remaining: 49.78 Minutes
# Completed loop 54k / 200k, Estimated Time Remaining: 48.01 Minutes
# Completed loop 55k / 200k, Estimated Time Remaining: 46.57 Minutes
# Completed loop 56k / 200k, Estimated Time Remaining: 49.85 Minutes
# Completed loop 57k / 200k, Estimated Time Remaining: 45.99 Minutes
# Completed loop 58k / 200k, Estimated Time Remaining: 48.72 Minutes
# Completed loop 59k / 200k, Estimated Time Remaining: 45.85 Minutes
# Completed loop 60k / 200k, Estimated Time Remaining: 47.36 Minutes
# Completed loop 61k / 200k, Estimated Time Remaining: 46.66 Minutes
# Completed loop 62k / 200k, Estimated Time Remaining: 44.67 Minutes
# Completed loop 63k / 200k, Estimated Time Remaining: 51.55 Minutes
# Completed loop 64k / 200k, Estimated Time Remaining: 44.23 Minutes
# Completed loop 65k / 200k, Estimated Time Remaining: 47.34 Minutes
# Completed loop 66k / 200k, Estimated Time Remaining: 44.38 Minutes
# Completed loop 67k / 200k, Estimated Time Remaining: 46.76 Minutes
# Completed loop 68k / 200k, Estimated Time Remaining: 43.33 Minutes
# Completed loop 69k / 200k, Estimated Time Remaining: 44.58 Minutes
# Completed loop 70k / 200k, Estimated Time Remaining: 43.55 Minutes
# Completed loop 71k / 200k, Estimated Time Remaining: 42.56 Minutes
# Completed loop 72k / 200k, Estimated Time Remaining: 45.05 Minutes
# Completed loop 73k / 200k, Estimated Time Remaining: 45.09 Minutes
# Completed loop 74k / 200k, Estimated Time Remaining: 44.44 Minutes
# Completed loop 75k / 200k, Estimated Time Remaining: 40.98 Minutes
# Completed loop 76k / 200k, Estimated Time Remaining: 44.41 Minutes
# Completed loop 77k / 200k, Estimated Time Remaining: 42.21 Minutes
# Completed loop 78k / 200k, Estimated Time Remaining: 47.10 Minutes
# Completed loop 79k / 200k, Estimated Time Remaining: 39.98 Minutes
# Completed loop 80k / 200k, Estimated Time Remaining: 42.59 Minutes
# Completed loop 81k / 200k, Estimated Time Remaining: 39.76 Minutes
# Completed loop 82k / 200k, Estimated Time Remaining: 41.30 Minutes
# Completed loop 83k / 200k, Estimated Time Remaining: 41.50 Minutes
# Completed loop 84k / 200k, Estimated Time Remaining: 42.78 Minutes
# Completed loop 85k / 200k, Estimated Time Remaining: 38.76 Minutes
# Completed loop 86k / 200k, Estimated Time Remaining: 40.11 Minutes
# Completed loop 87k / 200k, Estimated Time Remaining: 38.58 Minutes
# Completed loop 88k / 200k, Estimated Time Remaining: 38.57 Minutes
# Completed loop 89k / 200k, Estimated Time Remaining: 38.84 Minutes
# Completed loop 90k / 200k, Estimated Time Remaining: 37.73 Minutes
# Completed loop 91k / 200k, Estimated Time Remaining: 38.77 Minutes
# Completed loop 92k / 200k, Estimated Time Remaining: 36.13 Minutes
# Completed loop 93k / 200k, Estimated Time Remaining: 39.79 Minutes
# Completed loop 94k / 200k, Estimated Time Remaining: 43.30 Minutes
# Completed loop 95k / 200k, Estimated Time Remaining: 38.45 Minutes
# Completed loop 96k / 200k, Estimated Time Remaining: 40.20 Minutes
# Completed loop 97k / 200k, Estimated Time Remaining: 49.76 Minutes
# Completed loop 98k / 200k, Estimated Time Remaining: 51.90 Minutes
# Completed loop 99k / 200k, Estimated Time Remaining: 41.09 Minutes
# Completed loop 100k / 200k, Estimated Time Remaining: 40.78 Minutes
# Completed loop 101k / 200k, Estimated Time Remaining: 38.32 Minutes
# Completed loop 102k / 200k, Estimated Time Remaining: 38.94 Minutes
# Completed loop 103k / 200k, Estimated Time Remaining: 38.52 Minutes
# Completed loop 104k / 200k, Estimated Time Remaining: 35.72 Minutes
# Completed loop 105k / 200k, Estimated Time Remaining: 35.90 Minutes
# Completed loop 106k / 200k, Estimated Time Remaining: 45.74 Minutes
# Completed loop 107k / 200k, Estimated Time Remaining: 52.25 Minutes
# Completed loop 108k / 200k, Estimated Time Remaining: 45.82 Minutes
# Completed loop 109k / 200k, Estimated Time Remaining: 44.33 Minutes
# Completed loop 110k / 200k, Estimated Time Remaining: 47.26 Minutes
# Completed loop 111k / 200k, Estimated Time Remaining: 35.50 Minutes
# Completed loop 112k / 200k, Estimated Time Remaining: 30.87 Minutes
# Completed loop 113k / 200k, Estimated Time Remaining: 32.92 Minutes
# Completed loop 114k / 200k, Estimated Time Remaining: 31.53 Minutes
# Completed loop 115k / 200k, Estimated Time Remaining: 31.91 Minutes
# Completed loop 116k / 200k, Estimated Time Remaining: 33.07 Minutes
# Completed loop 117k / 200k, Estimated Time Remaining: 31.64 Minutes
# Completed loop 118k / 200k, Estimated Time Remaining: 39.28 Minutes
# Completed loop 119k / 200k, Estimated Time Remaining: 32.23 Minutes
# Completed loop 120k / 200k, Estimated Time Remaining: 30.07 Minutes
# Completed loop 121k / 200k, Estimated Time Remaining: 32.06 Minutes
# Completed loop 122k / 200k, Estimated Time Remaining: 31.97 Minutes
# Completed loop 123k / 200k, Estimated Time Remaining: 29.83 Minutes
# Completed loop 124k / 200k, Estimated Time Remaining: 31.55 Minutes
# Completed loop 125k / 200k, Estimated Time Remaining: 30.66 Minutes
# Completed loop 126k / 200k, Estimated Time Remaining: 29.07 Minutes
# Completed loop 127k / 200k, Estimated Time Remaining: 31.51 Minutes
# Completed loop 128k / 200k, Estimated Time Remaining: 30.07 Minutes
# Completed loop 129k / 200k, Estimated Time Remaining: 31.55 Minutes
# Completed loop 130k / 200k, Estimated Time Remaining: 28.88 Minutes
# Completed loop 131k / 200k, Estimated Time Remaining: 27.17 Minutes
# Completed loop 132k / 200k, Estimated Time Remaining: 27.68 Minutes
# Completed loop 133k / 200k, Estimated Time Remaining: 27.29 Minutes
# Completed loop 134k / 200k, Estimated Time Remaining: 26.91 Minutes
# Completed loop 135k / 200k, Estimated Time Remaining: 29.99 Minutes
# Completed loop 136k / 200k, Estimated Time Remaining: 26.18 Minutes
# Completed loop 137k / 200k, Estimated Time Remaining: 24.29 Minutes
# Completed loop 138k / 200k, Estimated Time Remaining: 25.57 Minutes
# Completed loop 139k / 200k, Estimated Time Remaining: 25.43 Minutes
# Completed loop 140k / 200k, Estimated Time Remaining: 22.76 Minutes
# Completed loop 141k / 200k, Estimated Time Remaining: 24.13 Minutes
# Completed loop 142k / 200k, Estimated Time Remaining: 24.24 Minutes
# Completed loop 143k / 200k, Estimated Time Remaining: 24.91 Minutes
# Completed loop 144k / 200k, Estimated Time Remaining: 23.86 Minutes
# Completed loop 145k / 200k, Estimated Time Remaining: 22.30 Minutes
# Completed loop 146k / 200k, Estimated Time Remaining: 20.90 Minutes
# Completed loop 147k / 200k, Estimated Time Remaining: 20.52 Minutes
# Completed loop 148k / 200k, Estimated Time Remaining: 21.26 Minutes
# Completed loop 149k / 200k, Estimated Time Remaining: 20.40 Minutes
# Completed loop 150k / 200k, Estimated Time Remaining: 19.50 Minutes
# Completed loop 151k / 200k, Estimated Time Remaining: 20.18 Minutes
# Completed loop 152k / 200k, Estimated Time Remaining: 20.91 Minutes
# Completed loop 153k / 200k, Estimated Time Remaining: 18.92 Minutes
# Completed loop 154k / 200k, Estimated Time Remaining: 18.00 Minutes
# Completed loop 155k / 200k, Estimated Time Remaining: 17.86 Minutes
# Completed loop 156k / 200k, Estimated Time Remaining: 16.59 Minutes
# Completed loop 157k / 200k, Estimated Time Remaining: 17.47 Minutes
# Completed loop 158k / 200k, Estimated Time Remaining: 16.96 Minutes
# Completed loop 159k / 200k, Estimated Time Remaining: 15.67 Minutes
# Completed loop 160k / 200k, Estimated Time Remaining: 16.55 Minutes
# Completed loop 161k / 200k, Estimated Time Remaining: 17.37 Minutes
# Completed loop 162k / 200k, Estimated Time Remaining: 15.49 Minutes
# Completed loop 163k / 200k, Estimated Time Remaining: 14.19 Minutes
# Completed loop 164k / 200k, Estimated Time Remaining: 14.40 Minutes
# Completed loop 165k / 200k, Estimated Time Remaining: 13.57 Minutes
# Completed loop 166k / 200k, Estimated Time Remaining: 13.09 Minutes
# Completed loop 167k / 200k, Estimated Time Remaining: 13.72 Minutes
# Completed loop 168k / 200k, Estimated Time Remaining: 13.85 Minutes
# Completed loop 169k / 200k, Estimated Time Remaining: 14.26 Minutes
# Completed loop 170k / 200k, Estimated Time Remaining: 12.43 Minutes
# Completed loop 171k / 200k, Estimated Time Remaining: 11.92 Minutes
# Completed loop 172k / 200k, Estimated Time Remaining: 11.13 Minutes
# Completed loop 173k / 200k, Estimated Time Remaining: 10.90 Minutes
# Completed loop 174k / 200k, Estimated Time Remaining: 10.90 Minutes
# Completed loop 175k / 200k, Estimated Time Remaining: 10.15 Minutes
# Completed loop 176k / 200k, Estimated Time Remaining: 9.28 Minutes
# Completed loop 177k / 200k, Estimated Time Remaining: 10.29 Minutes
# Completed loop 178k / 200k, Estimated Time Remaining: 9.29 Minutes
# Completed loop 179k / 200k, Estimated Time Remaining: 8.37 Minutes
# Completed loop 180k / 200k, Estimated Time Remaining: 8.37 Minutes
# Completed loop 181k / 200k, Estimated Time Remaining: 8.01 Minutes
# Completed loop 182k / 200k, Estimated Time Remaining: 7.52 Minutes
# Completed loop 183k / 200k, Estimated Time Remaining: 6.62 Minutes
# Completed loop 184k / 200k, Estimated Time Remaining: 6.61 Minutes
# Completed loop 185k / 200k, Estimated Time Remaining: 6.60 Minutes
# Completed loop 186k / 200k, Estimated Time Remaining: 5.77 Minutes
# Completed loop 187k / 200k, Estimated Time Remaining: 5.16 Minutes
# Completed loop 188k / 200k, Estimated Time Remaining: 4.92 Minutes
# Completed loop 189k / 200k, Estimated Time Remaining: 4.45 Minutes
# Completed loop 190k / 200k, Estimated Time Remaining: 3.85 Minutes
# Completed loop 191k / 200k, Estimated Time Remaining: 3.71 Minutes
# Completed loop 192k / 200k, Estimated Time Remaining: 3.28 Minutes
# Completed loop 193k / 200k, Estimated Time Remaining: 2.87 Minutes
# Completed loop 194k / 200k, Estimated Time Remaining: 2.86 Minutes
# Completed loop 195k / 200k, Estimated Time Remaining: 2.07 Minutes
# Completed loop 196k / 200k, Estimated Time Remaining: 1.67 Minutes
# Completed loop 197k / 200k, Estimated Time Remaining: 1.20 Minutes
# Completed loop 198k / 200k, Estimated Time Remaining: 0.81 Minutes
# Completed loop 199k / 200k, Estimated Time Remaining: 0.42 Minutes
# Completed loop 200k / 200k, Estimated Time Remaining: 0.00 Minutes
# Time to Train RL Model: 75.76 Minutes
# Environment Training R2 Score: 0.1957
# A/B/N Training R2 Score: 0.1957
# Environment Test R2 Score: 0.2080
# A/B/N Test R2 Score: 0.2080

# %%
import locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8') #for currency formatting

# Cumulative Reward Calculation and Display for df2
df2['Cumulative Reward'] = df2['Trip Price'] * df2['Utilization']
total_cumulative_reward_df2 = df2['Cumulative Reward'].sum()
formatted_reward = locale.currency(total_cumulative_reward_df2, grouping=True)
print(f"Total Cumulative Reward for df2: {formatted_reward}")
# Out:
# Total Cumulative Reward for df2: $5,349,205.34

# %% [markdown]
# ## Epsilon Greedy Model

# %%
# Epsilon-greedy strategy parameters
epsilon = 0.1  # Exploration rate (10% exploration)
candidate_prices = np.linspace(10, 150, 15)  # Prices to consider during exploitation

# Initialize model_3 (supervised learning model for exploitation)
preprocessor3 = ColumnTransformer(transformers=[('categorical', OneHotEncoder(sparse_output = False, handle_unknown = 'ignore'), categorical_list),
                                              ('numerical', MinMaxScaler(), numerical_list)], remainder='passthrough')

model_3 = make_pipeline(preprocessor3, LinearRegression())
model_3_trained = False

# Initialize
preprocessor1.fit(x_train)
df3 = pd.DataFrame(columns=['Utilization'] + x_train.columns.tolist())
num_iterations = len(x_train)
j = 0
last_time_check = time.time()

# Reinforcement Learning Loop
for i in range(num_iterations):
    # Get current environment features
    current_features = x_train.iloc[i][x_train.drop(columns='Trip Price').columns.tolist()]
    features_with_price = current_features.copy().to_dict()  # Ensure it's a dictionary

    # Epsilon-greedy decision
    if np.random.rand() < epsilon or not model_3_trained:
        # Exploration: Choose a random price
        agent_price = np.random.uniform(10, 150)

    else:
        # Exploitation: Maximize predicted utilization * price
        predicted_rewards = []
        for price in candidate_prices:
            # Add 'Trip Price' to the current features
            features_with_price['Trip Price'] = price
            features_with_price_df = pd.DataFrame([features_with_price])

            # Predict utilization using model_3
            utilization = model_3.predict(features_with_price_df)[0]
            predicted_rewards.append(utilization * price)

        # Select the price that maximizes utilization * price
        agent_price = candidate_prices[np.argmax(predicted_rewards)]

    # Create DataFrame and transform data
    features_with_price = current_features.copy().to_dict()
    features_with_price['Trip Price'] = agent_price
    features_with_price_df = pd.DataFrame([features_with_price])
    data_transformed = model_1.named_steps['columntransformer'].transform(features_with_price_df)

    # Predict utilization using supervised learning model #1
    utilization = model_1.named_steps['linearregression'].predict(data_transformed)[0]

    # Append the agent's data and predicted utilization to DataFrame 3
    new_row = {'Trip Price': agent_price, **current_features.to_dict(), 'Utilization': utilization}
    if df3.empty:
        df3 = pd.DataFrame([new_row])
    else:
        df3 = pd.concat([df3, pd.DataFrame([new_row])], ignore_index=True)

    # Create/Update supervised learning model_3 after collecting enough data, Retrain every 1,000 iterations after 10,000 samples
    if len(df3) > 10000 and i % 1000 == 0:  #this needs to be extended from 10,000 if the data doesn't see every sample (depending on dataset size)
        x3_train = df3.drop(columns=['Utilization'])
        y3_train = df3['Utilization']
        model_3.fit(x3_train, y3_train)
        model_3_trained = True

    j += 1
    if j % 1000 == 0:
        current_time = time.time()
        time_for_last_1000 = current_time - last_time_check
        remaining_iterations = (num_iterations - j) // 1000
        estimated_time_remaining = remaining_iterations * time_for_last_1000 / 60
        last_time_check = current_time
        print(f'Completed loop {j/1000:.0f}k / {num_iterations/1000:.0f}k,',
              f'Estimated Time Remaining: {estimated_time_remaining:.2f} Minutes')

# Train model one last time at the end
x3_train = df3.drop(columns=['Utilization'])
y3_train = df3['Utilization']
model_3.fit(x3_train, y3_train)

time_end = time.time()
print(f'Time to Train RL Model: {(time_end - time_start)/60:.2f} Minutes')

# Compare Agent's Model to the environment's model
environment_train = model_1.score(x_train, y_train)
print(f'Environment Training R2 Score: {environment_train:.4f}')

EGreedy_train = model_3.score(x_train, y_train)
print(f'EGreedy Training R2 Score: {EGreedy_train:.4f}')

environment_test = model_1.score(x_test, y_test)
print(f'Environment Test R2 Score: {environment_test:.4f}')

EGreedy_test = model_3.score(x_test, y_test)
print(f'EGreedy Test R2 Score: {EGreedy_test:.4f}')
# Out:
# Completed loop 1k / 200k, Estimated Time Remaining: 62.49 Minutes
# Completed loop 2k / 200k, Estimated Time Remaining: 67.17 Minutes
# Completed loop 3k / 200k, Estimated Time Remaining: 60.95 Minutes
# Completed loop 4k / 200k, Estimated Time Remaining: 60.22 Minutes
# Completed loop 5k / 200k, Estimated Time Remaining: 63.23 Minutes
# Completed loop 6k / 200k, Estimated Time Remaining: 60.84 Minutes
# Completed loop 7k / 200k, Estimated Time Remaining: 59.37 Minutes
# Completed loop 8k / 200k, Estimated Time Remaining: 64.02 Minutes
# Completed loop 9k / 200k, Estimated Time Remaining: 59.19 Minutes
# Completed loop 10k / 200k, Estimated Time Remaining: 58.90 Minutes
# Completed loop 11k / 200k, Estimated Time Remaining: 318.12 Minutes
# Completed loop 12k / 200k, Estimated Time Remaining: 306.99 Minutes
# Completed loop 13k / 200k, Estimated Time Remaining: 330.03 Minutes
# Completed loop 14k / 200k, Estimated Time Remaining: 308.70 Minutes
# Completed loop 15k / 200k, Estimated Time Remaining: 312.96 Minutes
# Completed loop 16k / 200k, Estimated Time Remaining: 304.48 Minutes
# Completed loop 17k / 200k, Estimated Time Remaining: 311.40 Minutes
# Completed loop 18k / 200k, Estimated Time Remaining: 299.61 Minutes
# Completed loop 19k / 200k, Estimated Time Remaining: 302.84 Minutes
# Completed loop 20k / 200k, Estimated Time Remaining: 293.72 Minutes
# Completed loop 21k / 200k, Estimated Time Remaining: 300.33 Minutes
# Completed loop 22k / 200k, Estimated Time Remaining: 297.85 Minutes
# Completed loop 23k / 200k, Estimated Time Remaining: 291.95 Minutes
# Completed loop 24k / 200k, Estimated Time Remaining: 292.09 Minutes
# Completed loop 25k / 200k, Estimated Time Remaining: 293.29 Minutes
# Completed loop 26k / 200k, Estimated Time Remaining: 290.53 Minutes
# Completed loop 27k / 200k, Estimated Time Remaining: 291.65 Minutes
# Completed loop 28k / 200k, Estimated Time Remaining: 284.74 Minutes
# Completed loop 29k / 200k, Estimated Time Remaining: 285.46 Minutes
# Completed loop 30k / 200k, Estimated Time Remaining: 284.67 Minutes
# Completed loop 31k / 200k, Estimated Time Remaining: 305.26 Minutes
# Completed loop 32k / 200k, Estimated Time Remaining: 276.80 Minutes
# Completed loop 33k / 200k, Estimated Time Remaining: 278.89 Minutes
# Completed loop 34k / 200k, Estimated Time Remaining: 280.65 Minutes
# Completed loop 35k / 200k, Estimated Time Remaining: 274.54 Minutes
# Completed loop 36k / 200k, Estimated Time Remaining: 272.90 Minutes
# Completed loop 37k / 200k, Estimated Time Remaining: 273.48 Minutes
# Completed loop 38k / 200k, Estimated Time Remaining: 274.75 Minutes
# Completed loop 39k / 200k, Estimated Time Remaining: 263.90 Minutes
# Completed loop 40k / 200k, Estimated Time Remaining: 268.54 Minutes
# Completed loop 41k / 200k, Estimated Time Remaining: 263.81 Minutes
# Completed loop 42k / 200k, Estimated Time Remaining: 261.73 Minutes
# Completed loop 43k / 200k, Estimated Time Remaining: 261.07 Minutes
# Completed loop 44k / 200k, Estimated Time Remaining: 255.23 Minutes
# Completed loop 45k / 200k, Estimated Time Remaining: 254.04 Minutes
# Completed loop 46k / 200k, Estimated Time Remaining: 248.77 Minutes
# Completed loop 47k / 200k, Estimated Time Remaining: 249.24 Minutes
# Completed loop 48k / 200k, Estimated Time Remaining: 247.79 Minutes
# Completed loop 49k / 200k, Estimated Time Remaining: 248.98 Minutes
# Completed loop 50k / 200k, Estimated Time Remaining: 245.83 Minutes
# Completed loop 51k / 200k, Estimated Time Remaining: 242.20 Minutes
# Completed loop 52k / 200k, Estimated Time Remaining: 237.29 Minutes
# Completed loop 53k / 200k, Estimated Time Remaining: 248.00 Minutes
# Completed loop 54k / 200k, Estimated Time Remaining: 240.05 Minutes
# Completed loop 55k / 200k, Estimated Time Remaining: 236.53 Minutes
# Completed loop 56k / 200k, Estimated Time Remaining: 235.96 Minutes
# Completed loop 57k / 200k, Estimated Time Remaining: 233.34 Minutes
# Completed loop 58k / 200k, Estimated Time Remaining: 230.86 Minutes
# Completed loop 59k / 200k, Estimated Time Remaining: 232.05 Minutes
# Completed loop 60k / 200k, Estimated Time Remaining: 230.96 Minutes
# Completed loop 61k / 200k, Estimated Time Remaining: 227.38 Minutes
# Completed loop 62k / 200k, Estimated Time Remaining: 227.27 Minutes
# Completed loop 63k / 200k, Estimated Time Remaining: 227.00 Minutes
# Completed loop 64k / 200k, Estimated Time Remaining: 222.50 Minutes
# Completed loop 65k / 200k, Estimated Time Remaining: 228.75 Minutes
# Completed loop 66k / 200k, Estimated Time Remaining: 218.83 Minutes
# Completed loop 67k / 200k, Estimated Time Remaining: 225.13 Minutes
# Completed loop 68k / 200k, Estimated Time Remaining: 227.74 Minutes
# Completed loop 69k / 200k, Estimated Time Remaining: 223.90 Minutes
# Completed loop 70k / 200k, Estimated Time Remaining: 220.15 Minutes
# Completed loop 71k / 200k, Estimated Time Remaining: 222.53 Minutes
# Completed loop 72k / 200k, Estimated Time Remaining: 217.08 Minutes
# Completed loop 73k / 200k, Estimated Time Remaining: 214.33 Minutes
# Completed loop 74k / 200k, Estimated Time Remaining: 215.39 Minutes
# Completed loop 75k / 200k, Estimated Time Remaining: 215.83 Minutes
# Completed loop 76k / 200k, Estimated Time Remaining: 207.33 Minutes
# Completed loop 77k / 200k, Estimated Time Remaining: 205.25 Minutes
# Completed loop 78k / 200k, Estimated Time Remaining: 204.86 Minutes
# Completed loop 79k / 200k, Estimated Time Remaining: 205.93 Minutes
# Completed loop 80k / 200k, Estimated Time Remaining: 200.61 Minutes
# Completed loop 81k / 200k, Estimated Time Remaining: 203.17 Minutes
# Completed loop 82k / 200k, Estimated Time Remaining: 199.40 Minutes
# Completed loop 83k / 200k, Estimated Time Remaining: 196.85 Minutes
# Completed loop 84k / 200k, Estimated Time Remaining: 192.81 Minutes
# Completed loop 85k / 200k, Estimated Time Remaining: 193.60 Minutes
# Completed loop 86k / 200k, Estimated Time Remaining: 192.79 Minutes
# Completed loop 87k / 200k, Estimated Time Remaining: 194.60 Minutes
# Completed loop 88k / 200k, Estimated Time Remaining: 193.90 Minutes
# Completed loop 89k / 200k, Estimated Time Remaining: 195.63 Minutes
# Completed loop 90k / 200k, Estimated Time Remaining: 194.18 Minutes
# Completed loop 91k / 200k, Estimated Time Remaining: 193.59 Minutes
# Completed loop 92k / 200k, Estimated Time Remaining: 188.39 Minutes
# Completed loop 93k / 200k, Estimated Time Remaining: 191.52 Minutes
# Completed loop 94k / 200k, Estimated Time Remaining: 189.84 Minutes
# Completed loop 95k / 200k, Estimated Time Remaining: 183.85 Minutes
# Completed loop 96k / 200k, Estimated Time Remaining: 184.11 Minutes
# Completed loop 97k / 200k, Estimated Time Remaining: 184.37 Minutes
# Completed loop 98k / 200k, Estimated Time Remaining: 180.89 Minutes
# Completed loop 99k / 200k, Estimated Time Remaining: 180.51 Minutes
# Completed loop 100k / 200k, Estimated Time Remaining: 177.46 Minutes
# Completed loop 101k / 200k, Estimated Time Remaining: 180.15 Minutes
# Completed loop 102k / 200k, Estimated Time Remaining: 176.06 Minutes
# Completed loop 103k / 200k, Estimated Time Remaining: 172.72 Minutes
# Completed loop 104k / 200k, Estimated Time Remaining: 172.20 Minutes
# Completed loop 105k / 200k, Estimated Time Remaining: 170.02 Minutes
# Completed loop 106k / 200k, Estimated Time Remaining: 166.38 Minutes
# Completed loop 107k / 200k, Estimated Time Remaining: 166.60 Minutes
# Completed loop 108k / 200k, Estimated Time Remaining: 165.86 Minutes
# Completed loop 109k / 200k, Estimated Time Remaining: 164.42 Minutes
# Completed loop 110k / 200k, Estimated Time Remaining: 159.31 Minutes
# Completed loop 111k / 200k, Estimated Time Remaining: 159.20 Minutes
# Completed loop 112k / 200k, Estimated Time Remaining: 154.61 Minutes
# Completed loop 113k / 200k, Estimated Time Remaining: 152.96 Minutes
# Completed loop 114k / 200k, Estimated Time Remaining: 154.15 Minutes
# Completed loop 115k / 200k, Estimated Time Remaining: 153.45 Minutes
# Completed loop 116k / 200k, Estimated Time Remaining: 151.53 Minutes
# Completed loop 117k / 200k, Estimated Time Remaining: 151.54 Minutes
# Completed loop 118k / 200k, Estimated Time Remaining: 153.17 Minutes
# Completed loop 119k / 200k, Estimated Time Remaining: 146.77 Minutes
# Completed loop 120k / 200k, Estimated Time Remaining: 143.17 Minutes
# Completed loop 121k / 200k, Estimated Time Remaining: 138.60 Minutes
# Completed loop 122k / 200k, Estimated Time Remaining: 138.74 Minutes
# Completed loop 123k / 200k, Estimated Time Remaining: 137.62 Minutes
# Completed loop 124k / 200k, Estimated Time Remaining: 134.92 Minutes
# Completed loop 125k / 200k, Estimated Time Remaining: 132.43 Minutes
# Completed loop 126k / 200k, Estimated Time Remaining: 132.47 Minutes
# Completed loop 127k / 200k, Estimated Time Remaining: 137.76 Minutes
# Completed loop 128k / 200k, Estimated Time Remaining: 135.15 Minutes
# Completed loop 129k / 200k, Estimated Time Remaining: 129.46 Minutes
# Completed loop 130k / 200k, Estimated Time Remaining: 127.24 Minutes
# Completed loop 131k / 200k, Estimated Time Remaining: 123.11 Minutes
# Completed loop 132k / 200k, Estimated Time Remaining: 122.11 Minutes
# Completed loop 133k / 200k, Estimated Time Remaining: 121.73 Minutes
# Completed loop 134k / 200k, Estimated Time Remaining: 120.40 Minutes
# Completed loop 135k / 200k, Estimated Time Remaining: 120.30 Minutes
# Completed loop 136k / 200k, Estimated Time Remaining: 120.70 Minutes
# Completed loop 137k / 200k, Estimated Time Remaining: 116.26 Minutes
# Completed loop 138k / 200k, Estimated Time Remaining: 114.68 Minutes
# Completed loop 139k / 200k, Estimated Time Remaining: 114.94 Minutes
# Completed loop 140k / 200k, Estimated Time Remaining: 110.50 Minutes
# Completed loop 141k / 200k, Estimated Time Remaining: 109.42 Minutes
# Completed loop 142k / 200k, Estimated Time Remaining: 108.41 Minutes
# Completed loop 143k / 200k, Estimated Time Remaining: 105.16 Minutes
# Completed loop 144k / 200k, Estimated Time Remaining: 104.85 Minutes
# Completed loop 145k / 200k, Estimated Time Remaining: 104.34 Minutes
# Completed loop 146k / 200k, Estimated Time Remaining: 101.65 Minutes
# Completed loop 147k / 200k, Estimated Time Remaining: 101.77 Minutes
# Completed loop 148k / 200k, Estimated Time Remaining: 98.65 Minutes
# Completed loop 149k / 200k, Estimated Time Remaining: 95.19 Minutes
# Completed loop 150k / 200k, Estimated Time Remaining: 91.45 Minutes
# Completed loop 151k / 200k, Estimated Time Remaining: 91.84 Minutes
# Completed loop 152k / 200k, Estimated Time Remaining: 90.10 Minutes
# Completed loop 153k / 200k, Estimated Time Remaining: 88.61 Minutes
# Completed loop 154k / 200k, Estimated Time Remaining: 86.04 Minutes
# Completed loop 155k / 200k, Estimated Time Remaining: 84.44 Minutes
# Completed loop 156k / 200k, Estimated Time Remaining: 83.12 Minutes
# Completed loop 157k / 200k, Estimated Time Remaining: 78.64 Minutes
# Completed loop 158k / 200k, Estimated Time Remaining: 78.39 Minutes
# Completed loop 159k / 200k, Estimated Time Remaining: 75.89 Minutes
# Completed loop 160k / 200k, Estimated Time Remaining: 73.25 Minutes
# Completed loop 161k / 200k, Estimated Time Remaining: 71.07 Minutes
# Completed loop 162k / 200k, Estimated Time Remaining: 70.57 Minutes
# Completed loop 163k / 200k, Estimated Time Remaining: 67.38 Minutes
# Completed loop 164k / 200k, Estimated Time Remaining: 65.39 Minutes
# Completed loop 165k / 200k, Estimated Time Remaining: 65.82 Minutes
# Completed loop 166k / 200k, Estimated Time Remaining: 62.57 Minutes
# Completed loop 167k / 200k, Estimated Time Remaining: 60.60 Minutes
# Completed loop 168k / 200k, Estimated Time Remaining: 58.92 Minutes
# Completed loop 169k / 200k, Estimated Time Remaining: 56.36 Minutes
# Completed loop 170k / 200k, Estimated Time Remaining: 53.77 Minutes
# Completed loop 171k / 200k, Estimated Time Remaining: 52.44 Minutes
# Completed loop 172k / 200k, Estimated Time Remaining: 49.60 Minutes
# Completed loop 173k / 200k, Estimated Time Remaining: 47.17 Minutes
# Completed loop 174k / 200k, Estimated Time Remaining: 47.98 Minutes
# Completed loop 175k / 200k, Estimated Time Remaining: 44.90 Minutes
# Completed loop 176k / 200k, Estimated Time Remaining: 42.32 Minutes
# Completed loop 177k / 200k, Estimated Time Remaining: 41.11 Minutes
# Completed loop 178k / 200k, Estimated Time Remaining: 38.92 Minutes
# Completed loop 179k / 200k, Estimated Time Remaining: 37.25 Minutes
# Completed loop 180k / 200k, Estimated Time Remaining: 35.52 Minutes
# Completed loop 181k / 200k, Estimated Time Remaining: 33.68 Minutes
# Completed loop 182k / 200k, Estimated Time Remaining: 32.25 Minutes
# Completed loop 183k / 200k, Estimated Time Remaining: 30.50 Minutes
# Completed loop 184k / 200k, Estimated Time Remaining: 28.68 Minutes
# Completed loop 185k / 200k, Estimated Time Remaining: 26.59 Minutes
# Completed loop 186k / 200k, Estimated Time Remaining: 25.09 Minutes
# Completed loop 187k / 200k, Estimated Time Remaining: 23.11 Minutes
# Completed loop 188k / 200k, Estimated Time Remaining: 20.93 Minutes
# Completed loop 189k / 200k, Estimated Time Remaining: 19.42 Minutes
# Completed loop 190k / 200k, Estimated Time Remaining: 17.92 Minutes
# Completed loop 191k / 200k, Estimated Time Remaining: 15.92 Minutes
# Completed loop 192k / 200k, Estimated Time Remaining: 14.42 Minutes
# Completed loop 193k / 200k, Estimated Time Remaining: 12.85 Minutes
# Completed loop 194k / 200k, Estimated Time Remaining: 11.07 Minutes
# Completed loop 195k / 200k, Estimated Time Remaining: 11.00 Minutes
# Completed loop 196k / 200k, Estimated Time Remaining: 8.23 Minutes
# Completed loop 197k / 200k, Estimated Time Remaining: 6.08 Minutes
# Completed loop 198k / 200k, Estimated Time Remaining: 4.20 Minutes
# Completed loop 199k / 200k, Estimated Time Remaining: 2.00 Minutes
# Completed loop 200k / 200k, Estimated Time Remaining: 0.00 Minutes
# Time to Train RL Model: 414.81 Minutes
# Environment Training R2 Score: 0.1957
# EGreedy Training R2 Score: 0.1957
# Environment Test R2 Score: 0.2080
# EGreedy Test R2 Score: 0.2080

# %%
# Cumulative reward calculation and display for df3
df3['Cumulative Reward'] = df3['Trip Price'] * df3['Utilization']
total_cumulative_reward_df3 = df3['Cumulative Reward'].sum()
formatted_reward_df3 = locale.currency(total_cumulative_reward_df3, grouping=True)
print(f"Total Cumulative Reward for df3: {formatted_reward_df3}")
# Out:
# Total Cumulative Reward for df3: $11,314,715.16

# %% [markdown]
# ### Summary

# %%
#ABN model time and cumulative Reward
print(f"ABN Training Time: 75.76 Minutes") #hard coding due to overwrite from E-greedy
print(f"Total Cumulative Reward for df2: {formatted_reward}")

#Epsilon greedy model time and cumulative reward
EGreedy_total_time = (time_end - time_start) / 60  #time in minutes
print(f"Epsilon Greedy Training Time: {EGreedy_total_time:.2f} minutes")
print(f"Total Cumulative Reward for df3: {formatted_reward_df3}")
# Out:
# ABN Training Time: 75.76 Minutes
# Total Cumulative Reward for df2: $5,349,205.34
# Epsilon Greedy Training Time: 414.81 minutes
# Total Cumulative Reward for df3: $11,314,715.16

# %% [markdown]
# # Feature Importance of the Three models

# %%
#model 1
model_1_feature_names = model_1.named_steps['columntransformer'].get_feature_names_out()
model_1_coefficients = model_1.named_steps['linearregression'].coef_
model_1_coef_df = pd.DataFrame({'Feature': model_1_feature_names, 'Environment Coefficients': model_1_coefficients})
model_1_coef_df['Environment Absolute Coefficients'] = model_1_coef_df['Environment Coefficients'].abs()

#model 2
model_2_feature_names = model_2.named_steps['columntransformer'].get_feature_names_out()
model_2_coefficients = model_2.named_steps['linearregression'].coef_
model_2_coef_df = pd.DataFrame({'Feature': model_2_feature_names, 'A/B/N Coefficients': model_2_coefficients})
model_2_coef_df['A/B/N Absolute Coefficients'] = model_2_coef_df['A/B/N Coefficients'].abs()

#model 3
model_3_feature_names = model_3.named_steps['columntransformer'].get_feature_names_out()
model_3_coefficients = model_3.named_steps['linearregression'].coef_
model_3_coef_df = pd.DataFrame({'Feature': model_3_feature_names, 'EGreedy Coefficients': model_3_coefficients})
model_3_coef_df['EGreedy Absolute Coefficients'] = model_3_coef_df['EGreedy Coefficients'].abs()

#combined Dataframe for all coefficients
merged = pd.merge(model_1_coef_df, model_2_coef_df, on='Feature')
all_model_features = pd.merge(merged, model_3_coef_df, on='Feature')
all_model_features = all_model_features.sort_values(by='Environment Absolute Coefficients', ascending=False)

cols = all_model_features.columns[1:]
for col in cols:
    all_model_features[col] = all_model_features[col].apply(lambda x: float("{:.2e}".format(x)))

pd.options.display.max_rows = None
all_model_features
# Out:
#                                               Feature  \
# 26  categorical__Car ID Hash_d719907bc88b06eadc7ef...
# 23  categorical__Car ID Hash_c0050d79423575ee7e2b3...
# 12  categorical__Car ID Hash_5cfeba13d65aaea9e7462...
# 40    categorical__Car Parking Address Postcode_94133
# 28  categorical__Car ID Hash_e913321219505fb67071c...
# 22  categorical__Car ID Hash_b9bad70674669b3ac9d3a...
# 4   categorical__Car ID Hash_081ba0bd4491bc7958a36...
# 29  categorical__Car ID Hash_f71f8651e3fa154855271...
# 6   categorical__Car ID Hash_26c6519fa6cb24389eed6...
# 13  categorical__Car ID Hash_6c3e1812633ac44d768d9...
# 8   categorical__Car ID Hash_3d0cb9e44b66856366c1f...
# 24  categorical__Car ID Hash_c3bedd1001dd755b449c1...
# 62                          categorical__Start Hour_2
# 64                          categorical__Start Hour_4
# 61                          categorical__Start Hour_1
# 63                          categorical__Start Hour_3
# 60                          categorical__Start Hour_0
# 65                          categorical__Start Hour_5
# 67                          categorical__Start Hour_7
# 68                          categorical__Start Hour_8
# 82                         categorical__Start Hour_22
# 66                          categorical__Start Hour_6
# 70                         categorical__Start Hour_10
# 69                          categorical__Start Hour_9
# 71                         categorical__Start Hour_11
# 79                         categorical__Start Hour_19
# 78                         categorical__Start Hour_18
# 80                         categorical__Start Hour_20
# 75                         categorical__Start Hour_15
# 73                         categorical__Start Hour_13
# 77                         categorical__Start Hour_17
# 74                         categorical__Start Hour_14
# 72                         categorical__Start Hour_12
# 81                         categorical__Start Hour_21
# 76                         categorical__Start Hour_16
# 83                         categorical__Start Hour_23
# 30    categorical__Car Parking Address Postcode_94102
# 35    categorical__Car Parking Address Postcode_94114
# 3   categorical__Car ID Hash_0804968878f0b9c1a5b60...
# 37    categorical__Car Parking Address Postcode_94117
# 34    categorical__Car Parking Address Postcode_94112
# 19  categorical__Car ID Hash_a6bc23db01b597f8eee23...
# 21  categorical__Car ID Hash_b5e9271dd09182abab262...
# 1   categorical__Car ID Hash_009e6d8c899c9ad807e38...
# 31    categorical__Car Parking Address Postcode_94103
# 11  categorical__Car ID Hash_5328fd8804d7560958b4e...
# 0   categorical__Car ID Hash_001881b594721c5b169be...
# 25  categorical__Car ID Hash_d63ded6ed04143a881312...
# 20  categorical__Car ID Hash_b1512d5d9b6140eb34157...
# 18  categorical__Car ID Hash_a4146ec8abbd83af7efb2...
# 15  categorical__Car ID Hash_9ddbdce433138241891c9...
# 10  categorical__Car ID Hash_4ee389e31ed04c83df66d...
# 9   categorical__Car ID Hash_3df361f96e43c349736ef...
# 17  categorical__Car ID Hash_a3f1390ab54506dc57de7...
# 39    categorical__Car Parking Address Postcode_94124
# 32    categorical__Car Parking Address Postcode_94109
# 41          categorical__Start Day of the Week_Friday
# 43        categorical__Start Day of the Week_Saturday
# 45        categorical__Start Day of the Week_Thursday
# 44          categorical__Start Day of the Week_Sunday
# 46         categorical__Start Day of the Week_Tuesday
# 47       categorical__Start Day of the Week_Wednesday
# 42          categorical__Start Day of the Week_Monday
# 33    categorical__Car Parking Address Postcode_94110
# 5   categorical__Car ID Hash_137728acf85b981e54b1a...
# 16  categorical__Car ID Hash_9fffcd12a3f853c743a9e...
# 7   categorical__Car ID Hash_31daeb68bf1fd988e7dcf...
# 27  categorical__Car ID Hash_de1e26c20ef2eaf747792...
# 14  categorical__Car ID Hash_76aa6d08190734decd6ab...
# 2   categorical__Car ID Hash_02335d542bb4b1b2b9fda...
# 38    categorical__Car Parking Address Postcode_94122
# 57                  categorical__Start Month_November
# 58                   categorical__Start Month_October
# 50                  categorical__Start Month_December
# 56                       categorical__Start Month_May
# 54                      categorical__Start Month_June
# 53                      categorical__Start Month_July
# 59                 categorical__Start Month_September
# 52                   categorical__Start Month_January
# 55                     categorical__Start Month_March
# 49                    categorical__Start Month_August
# 48                     categorical__Start Month_April
# 51                  categorical__Start Month_February
# 36    categorical__Car Parking Address Postcode_94115
# 84                              numerical__Trip Price
# 85                          numerical__Hours Duration
# 86          numerical__Booking Advance Hours Duration
# 87     numerical__Price to Average Price Per Postcode
#
#     Environment Coefficients  Environment Absolute Coefficients  \
# 26             -5.810000e+12                       5.810000e+12
# 23             -5.810000e+12                       5.810000e+12
# 12             -5.810000e+12                       5.810000e+12
# 40              5.100000e+12                       5.100000e+12
# 28             -2.820000e+12                       2.820000e+12
# 22             -2.820000e+12                       2.820000e+12
# 4              -2.820000e+12                       2.820000e+12
# 29             -2.820000e+12                       2.820000e+12
# 6              -2.800000e+12                       2.800000e+12
# 13             -2.800000e+12                       2.800000e+12
# 8              -2.800000e+12                       2.800000e+12
# 24             -2.800000e+12                       2.800000e+12
# 62              2.580000e+12                       2.580000e+12
# 64              2.580000e+12                       2.580000e+12
# 61              2.580000e+12                       2.580000e+12
# 63              2.580000e+12                       2.580000e+12
# 60              2.580000e+12                       2.580000e+12
# 65              2.580000e+12                       2.580000e+12
# 67              2.580000e+12                       2.580000e+12
# 68              2.580000e+12                       2.580000e+12
# 82              2.580000e+12                       2.580000e+12
# 66              2.580000e+12                       2.580000e+12
# 70              2.580000e+12                       2.580000e+12
# 69              2.580000e+12                       2.580000e+12
# 71              2.580000e+12                       2.580000e+12
# 79              2.580000e+12                       2.580000e+12
# 78              2.580000e+12                       2.580000e+12
# 80              2.580000e+12                       2.580000e+12
# 75              2.580000e+12                       2.580000e+12
# 73              2.580000e+12                       2.580000e+12
# 77              2.580000e+12                       2.580000e+12
# 74              2.580000e+12                       2.580000e+12
# 72              2.580000e+12                       2.580000e+12
# 81              2.580000e+12                       2.580000e+12
# 76              2.580000e+12                       2.580000e+12
# 83              2.580000e+12                       2.580000e+12
# 30              2.110000e+12                       2.110000e+12
# 35              2.090000e+12                       2.090000e+12
# 3              -1.370000e+12                       1.370000e+12
# 37             -1.230000e+12                       1.230000e+12
# 34             -1.200000e+12                       1.200000e+12
# 19             -1.160000e+12                       1.160000e+12
# 21             -8.060000e+11                       8.060000e+11
# 1              -8.060000e+11                       8.060000e+11
# 31              6.570000e+11                       6.570000e+11
# 11              5.140000e+11                       5.140000e+11
# 0               5.140000e+11                       5.140000e+11
# 25              4.790000e+11                       4.790000e+11
# 20              4.790000e+11                       4.790000e+11
# 18             -4.630000e+11                       4.630000e+11
# 15             -4.630000e+11                       4.630000e+11
# 10             -4.630000e+11                       4.630000e+11
# 9              -4.630000e+11                       4.630000e+11
# 17             -4.630000e+11                       4.630000e+11
# 39             -4.560000e+11                       4.560000e+11
# 32              4.450000e+11                       4.450000e+11
# 41              4.350000e+11                       4.350000e+11
# 43              4.350000e+11                       4.350000e+11
# 45              4.350000e+11                       4.350000e+11
# 44              4.350000e+11                       4.350000e+11
# 46              4.350000e+11                       4.350000e+11
# 47              4.350000e+11                       4.350000e+11
# 42              4.350000e+11                       4.350000e+11
# 33             -4.320000e+11                       4.320000e+11
# 5              -2.840000e+11                       2.840000e+11
# 16             -2.840000e+11                       2.840000e+11
# 7              -2.840000e+11                       2.840000e+11
# 27             -2.840000e+11                       2.840000e+11
# 14             -2.840000e+11                       2.840000e+11
# 2              -2.600000e+11                       2.600000e+11
# 38             -2.530000e+11                       2.530000e+11
# 57              2.260000e+11                       2.260000e+11
# 58              2.260000e+11                       2.260000e+11
# 50              2.260000e+11                       2.260000e+11
# 56              2.260000e+11                       2.260000e+11
# 54              2.260000e+11                       2.260000e+11
# 53              2.260000e+11                       2.260000e+11
# 59              2.260000e+11                       2.260000e+11
# 52              2.260000e+11                       2.260000e+11
# 55              2.260000e+11                       2.260000e+11
# 49              2.260000e+11                       2.260000e+11
# 48              2.260000e+11                       2.260000e+11
# 51              2.260000e+11                       2.260000e+11
# 36              8.990000e+10                       8.990000e+10
# 84              9.260000e-01                       9.260000e-01
# 85              4.260000e-01                       4.260000e-01
# 86              1.820000e-01                       1.820000e-01
# 87             -2.200000e-02                       2.200000e-02
#
#     A/B/N Coefficients  A/B/N Absolute Coefficients  EGreedy Coefficients  \
# 26        4.140000e+09                 4.140000e+09          4.500000e+09
# 23        4.140000e+09                 4.140000e+09          4.500000e+09
# 12        4.140000e+09                 4.140000e+09          4.500000e+09
# 40       -3.340000e+09                 3.340000e+09         -1.860000e+09
# 28       -2.230000e+08                 2.230000e+08          2.080000e+09
# 22       -2.230000e+08                 2.230000e+08          2.080000e+09
# 4        -2.230000e+08                 2.230000e+08          2.080000e+09
# 29       -2.230000e+08                 2.230000e+08          2.080000e+09
# 6         1.170000e+09                 1.170000e+09          3.870000e+09
# 13        1.170000e+09                 1.170000e+09          3.870000e+09
# 8         1.170000e+09                 1.170000e+09          3.870000e+09
# 24        1.170000e+09                 1.170000e+09          3.870000e+09
# 62       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 64       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 61       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 63       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 60       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 65       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 67       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 68       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 82       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 66       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 70       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 69       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 71       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 79       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 78       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 80       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 75       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 73       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 77       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 74       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 72       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 81       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 76       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 83       -3.350000e+09                 3.350000e+09         -4.200000e+09
# 30        1.030000e+09                 1.030000e+09          5.630000e+08
# 35       -3.640000e+08                 3.640000e+08         -1.230000e+09
# 3         2.280000e+08                 2.280000e+08          1.970000e+09
# 37        4.640000e+08                 4.640000e+08          2.170000e+09
# 34       -3.980000e+06                 3.980000e+06         -1.900000e+08
# 19        5.080000e+09                 5.080000e+09         -6.360000e+09
# 21        1.240000e+08                 1.240000e+08          1.800000e+09
# 1         1.240000e+08                 1.240000e+08          1.800000e+09
# 31        5.770000e+08                 5.770000e+08          6.730000e+08
# 11        3.410000e+08                 3.410000e+08          4.700000e+08
# 0         3.410000e+08                 3.410000e+08          4.700000e+08
# 25        8.090000e+08                 8.090000e+08          2.830000e+09
# 20        8.090000e+08                 8.090000e+08          2.830000e+09
# 18        3.170000e+07                 3.170000e+07          2.410000e+09
# 15        3.170000e+07                 3.170000e+07          2.410000e+09
# 10        3.170000e+07                 3.170000e+07          2.410000e+09
# 9         3.170000e+07                 3.170000e+07          2.410000e+09
# 17        3.170000e+07                 3.170000e+07          2.410000e+09
# 39       -7.420000e+08                 7.420000e+08         -7.360000e+08
# 32       -4.280000e+09                 4.280000e+09          9.000000e+09
# 41        1.130000e+09                 1.130000e+09          1.100000e+09
# 43        1.130000e+09                 1.130000e+09          1.100000e+09
# 45        1.130000e+09                 1.130000e+09          1.100000e+09
# 44        1.130000e+09                 1.130000e+09          1.100000e+09
# 46        1.130000e+09                 1.130000e+09          1.100000e+09
# 47        1.130000e+09                 1.130000e+09          1.100000e+09
# 42        1.130000e+09                 1.130000e+09          1.100000e+09
# 33       -4.010000e+08                 4.010000e+08         -2.850000e+08
# 5         1.210000e+09                 1.210000e+09          2.930000e+09
# 16        1.210000e+09                 1.210000e+09          2.930000e+09
# 7         1.210000e+09                 1.210000e+09          2.930000e+09
# 27        1.210000e+09                 1.210000e+09          2.930000e+09
# 14        1.210000e+09                 1.210000e+09          2.930000e+09
# 2         1.550000e+09                 1.550000e+09          3.380000e+09
# 38        7.730000e+08                 7.730000e+08          2.260000e+08
# 57       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 58       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 50       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 56       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 54       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 53       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 59       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 52       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 55       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 49       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 48       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 51       -2.380000e+09                 2.380000e+09         -2.460000e+09
# 36        6.810000e+08                 6.810000e+08          8.430000e+08
# 84        2.140000e-01                 2.140000e-01          2.150000e-01
# 85        4.260000e-01                 4.260000e-01          4.260000e-01
# 86        1.820000e-01                 1.820000e-01          1.820000e-01
# 87       -2.200000e-02                 2.200000e-02         -2.200000e-02
#
#     EGreedy Absolute Coefficients
# 26                   4.500000e+09
# 23                   4.500000e+09
# 12                   4.500000e+09
# 40                   1.860000e+09
# 28                   2.080000e+09
# 22                   2.080000e+09
# 4                    2.080000e+09
# 29                   2.080000e+09
# 6                    3.870000e+09
# 13                   3.870000e+09
# 8                    3.870000e+09
# 24                   3.870000e+09
# 62                   4.200000e+09
# 64                   4.200000e+09
# 61                   4.200000e+09
# 63                   4.200000e+09
# 60                   4.200000e+09
# 65                   4.200000e+09
# 67                   4.200000e+09
# 68                   4.200000e+09
# 82                   4.200000e+09
# 66                   4.200000e+09
# 70                   4.200000e+09
# 69                   4.200000e+09
# 71                   4.200000e+09
# 79                   4.200000e+09
# 78                   4.200000e+09
# 80                   4.200000e+09
# 75                   4.200000e+09
# 73                   4.200000e+09
# 77                   4.200000e+09
# 74                   4.200000e+09
# 72                   4.200000e+09
# 81                   4.200000e+09
# 76                   4.200000e+09
# 83                   4.200000e+09
# 30                   5.630000e+08
# 35                   1.230000e+09
# 3                    1.970000e+09
# 37                   2.170000e+09
# 34                   1.900000e+08
# 19                   6.360000e+09
# 21                   1.800000e+09
# 1                    1.800000e+09
# 31                   6.730000e+08
# 11                   4.700000e+08
# 0                    4.700000e+08
# 25                   2.830000e+09
# 20                   2.830000e+09
# 18                   2.410000e+09
# 15                   2.410000e+09
# 10                   2.410000e+09
# 9                    2.410000e+09
# 17                   2.410000e+09
# 39                   7.360000e+08
# 32                   9.000000e+09
# 41                   1.100000e+09
# 43                   1.100000e+09
# 45                   1.100000e+09
# 44                   1.100000e+09
# 46                   1.100000e+09
# 47                   1.100000e+09
# 42                   1.100000e+09
# 33                   2.850000e+08
# 5                    2.930000e+09
# 16                   2.930000e+09
# 7                    2.930000e+09
# 27                   2.930000e+09
# 14                   2.930000e+09
# 2                    3.380000e+09
# 38                   2.260000e+08
# 57                   2.460000e+09
# 58                   2.460000e+09
# 50                   2.460000e+09
# 56                   2.460000e+09
# 54                   2.460000e+09
# 53                   2.460000e+09
# 59                   2.460000e+09
# 52                   2.460000e+09
# 55                   2.460000e+09
# 49                   2.460000e+09
# 48                   2.460000e+09
# 51                   2.460000e+09
# 36                   8.430000e+08
# 84                   2.150000e-01
# 85                   4.260000e-01
# 86                   1.820000e-01
# 87                   2.200000e-02
